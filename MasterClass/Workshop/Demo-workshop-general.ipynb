# %% [markdown]
# By this part, you will be able to implement a program where a user can enter simple input, the program can make choices based on some conditions and after calculation, results can be printed.
#
# Goals:
#
#     1. implement and run your python program in your local machine.
#
# Steps:
#
#     install Python on your machine.
#
#     Open terminal and check the version of your Python using command : python --version
#
#     Chose your editor to implement a program and save the file in your local machine.
#
#     Execute your firts program.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.12.2

# %% [markdown]
# Assignment 1: Check if a number is even or odd
#
# In this short exercise, you will learn how to:
# - Get input from the user
# - Check if the input is a valid integer
# - Use conditions to decide even or odd

# %%
number = int(input ("inter a number: "))

if number % 2 == 0:
    print("That is an even number")
else:
    print("That is an odd number")
# Out:
# That is an odd number

# %% [markdown]
# input() gets a number from the user.
#
# int() converts it from a string to an integer.
#
# % is the modulo operator (gives remainder).
#
# if num % 2 == 0 checks if the number divides evenly by 2.
#
# Assignment: Ask the user to enter a number and print whether it is even or odd.
# If the input is not a valid integer, print an error message.

# %%
#assignment: Check if a number is even or odd
user_input = input ("inter a number: ")
try:
    number = int(user_input)
    
    if number % 2 == 0:
        print("That is an even number")
    else:
        print("That is an odd number")
except ValueError:
    print("That is not an integer, please enter a valid integer.")
# Out:
# That is an even number

# %% [markdown]
# <h2 style="color:teal;"> What is a Function in Python?</h2>
#
# <p><strong style="color:blue;">A function</strong> is a reusable block of code that performs a specific task. It can take inputs (called arguments) and may return a result.
# Here are a few you're already using: </p>
#
#   - print()	 Displays output on the screen
#
# print("Hello!") → Hello!
#
#    - int()	Converts a value to an integer	int("42") → 42
#
#    - input()	Gets text input from the user	name = input("Enter name: ")
#
#   - type()	Returns the data type of a value	type(5) → <class 'int'>
#
#   - len()	Returns the length of a sequence	len("hello") → 5

# %%
print("Hello, World!")

x = int("3")
print("velue of x is", x)  # Outputs: 3

print("data type of x is: ", type(x))  # Outputs: <class 'int'>

print("integer of 4.7 is", int(4.7))  # Outputs: 4

print("x + 2 is", x + 2)  # Outputs: 5

#y = int("abc")  # This will raise a ValueError
# Out:
# Hello, World!
# velue of x is 3
# data type of x is:  <class 'int'>
# integer of 4.7 is 4
# x + 2 is 5

# %%
#len("hello")  # Outputs: 5
len([1, 2, 3, 4])  # Outputs: 4
# Out:
# 4

# %% [markdown]
# You can define your own function using the <code style="color:green;">def</code> keyword.
#
# ---
#
# <h3 style="color:purple;">Function Syntax</h3>
#
# ```python
# def function_name(parameters):
#     # code block
#     return result
#
#  def — keyword to define a function
#
# function_name — the name you choose
#
#
# parameters — input values to the function
#
#
# return — (optional) sends a result back
#
# Assignment 2: create a function that greets a person by name.

# %%
def greet(name):
    return "Hello, " + name + "! Nice to meet you."

greeting = greet("Job")
print(greeting)  # Outputs: Hello, Alice!
# Out:
# Hello, Job! Nice to meet you.

# %% [markdown]
# Assignment : <h5 style="color:lightblue;"> Convert Even/Odd Checker into a Function</h5>

# %%
def check_even_or_odd(user_input):
    try:
        number = int(user_input)
        if number % 2 == 0:
            print("That is an even number.")
        else:
            print("That is an odd number.")
    except ValueError:
        print("Please enter a valid integer.")

# %% [markdown]
# How to use it:

# %%
# Ask the user for input
user_input = input("Enter a number: ")

# Call the function with the user's input
check_even_or_odd(user_input)
# Out:
# That is an odd number.

# %%
text = "Hello world"
text.split()[0]
# Out:
# 'Hello'

# %%
list_of_numbers = [1, 2, 3, 4, 5]
list_of_numbers[0:3]
# Out:
# [1, 2, 3]

# %%
#i=0
for i in list_of_numbers:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## How to Debug in Python?
#
# 1. Use print() statements

# %%
def divide(a, b):
    print("a:", a, "b:", b)
    answer = a / b
    return answer

print(divide(10, 0))  #  ZeroDivisionError
#divide(10, 0)  # This will raise a ZeroDivisionError
# Out:
# a: 10 b: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 6
#       3     answer = a / b
#       4     return answer
# ----> 6 print(divide(10, 0))  #  ZeroDivisionError
#       7 #divide(10, 0)  # This will raise a ZeroDivisionError
#
# Cell In[26], line 3, in divide(a, b)
#       1 def divide(a, b):
#       2     print("a:", a, "b:", b)
# ----> 3     answer = a / b
#       4     return answer
#
# ZeroDivisionError: division by zero

# %% [markdown]
# From one value to many values
#
# Earlier: You asked the user to enter one number and checked if it was even or odd.
#
# Now: You read a list of numbers from a CSV file and do the same thing — just at scale.
#
# <p><strong style="color:blue;">Pandas</strong> is a Python library that makes it easy to:
#
# - Work with tables of data
#
# - Read data from CSV files, Excel files, etc.
#
# - Do filtering, sorting, statistics, and more

# %%
import pandas as pd

# %%
#df = pd.read_excel("Demo-contract.xlsx")
df = pd.read_csv("Demo-workshop.csv",sep= ",")
df.head()
# Out:
#   ContractBK  PersonBK   StartDate     EndDate  HoursPerWeek FunctionCode  \
# 0      C-001      1001  2024-01-01  2024-12-31            36        NURSE
# 1      C-002      1002  2024-02-01  2024-12-31            32        ADMIN
# 2      C-003      1003  2024-03-01         NaN            28        NURSE
#
#   LocationCode
# 0           L1
# 1           L2
# 2           L1

# %%
#Filter Rows by Column Value
person = df[df['PersonBK'] == 1001]

person
# Out:
#   ContractBK  PersonBK   StartDate     EndDate  HoursPerWeek FunctionCode  \
# 0      C-001      1001  2024-01-01  2024-12-31            36        NURSE
#
#   LocationCode
# 0           L1

# %%
full_time_hours = df[df["HoursPerWeek"] == 36]
full_time_hours
# Out:
#   ContractBK  PersonBK   StartDate     EndDate  HoursPerWeek FunctionCode  \
# 0      C-001      1001  2024-01-01  2024-12-31            36        NURSE
#
#   LocationCode
# 0           L1

# %%
def check_even_or_odd_csv(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

# %%
#df["odd_or_even"] = df["HoursPerWeek"].apply(lambda x: "Even" if x % 2 == 0 else "Odd")
df['odd_or_even'] = df['HoursPerWeek'].apply(check_even_or_odd_csv)
df.head()
# Out:
#   ContractBK  PersonBK   StartDate     EndDate  HoursPerWeek FunctionCode  \
# 0      C-001      1001  2024-01-01  2024-12-31            36        NURSE
# 1      C-002      1002  2024-02-01  2024-12-31            32        ADMIN
# 2      C-003      1003  2024-03-01         NaN            28        NURSE
#
#   LocationCode odd_or_even
# 0           L1        Even
# 1           L2        Even
# 2           L1        Even

# %%
df['parttimepercent'] =df['HoursPerWeek'].apply(lambda x: round((x / 36.0) * 100))
df.head()
# Out:
#   ContractBK  PersonBK   StartDate     EndDate  HoursPerWeek FunctionCode  \
# 0      C-001      1001  2024-01-01  2024-12-31            36        NURSE
# 1      C-002      1002  2024-02-01  2024-12-31            32        ADMIN
# 2      C-003      1003  2024-03-01         NaN            28        NURSE
#
#   LocationCode odd_or_even  parttimepercent
# 0           L1        Even              100
# 1           L2        Even               89
# 2           L1        Even               78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ContractBK       3 non-null      object
#  1   PersonBK         3 non-null      int64
#  2   StartDate        3 non-null      object
#  3   EndDate          2 non-null      object
#  4   HoursPerWeek     3 non-null      int64
#  5   FunctionCode     3 non-null      object
#  6   LocationCode     3 non-null      object
#  7   odd_or_even      3 non-null      object
#  8   parttimepercent  3 non-null      int64
# dtypes: int64(3), object(6)
# memory usage: 348.0+ bytes

# %%
output = df.to_csv("Demo-workshop-modified.csv", index=False)

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace
from rdflib.namespace import RDFS, XSD

# %%
# Define common namespace URIs
#version = 3.0.0
schema = Namespace('https://schema.org/#')
ex = Namespace('http://example.org/id#')

# %%
g = rdflib.Graph()

# %%
# Bind the namespace as the default namespace
g.bind("schema", schema)
g.bind("ex", ex)

# %%
df_people = pd.read_csv("people.csv", sep= ";")
df_people.head()
# Out:
#    id       name              email   birthdate
# 0   1  Alice Doe  alice@example.org  12/04/1990
# 1   2  Bob Smith    bob@example.org  30/10/1985

# %%
df_events= pd.read_csv("events.csv",sep=";")
df_events.head()
# Out:
#   event_id            title        date  organiser_id
# 0     E100  Health Workshop  01/03/2024             1
# 1     E101      Data Summit  15/05/2024             2

# %%
headers = df_people.columns.tolist()
for index, row in df_people.iterrows():
    try:
        # Validate required fields exist
        if pd.isna(row['name']):
            print(f"Row {index} skipped: 'name' missing.")
            continue

        person_uri = ex[f"person/{row['id']}"]
        g.add((person_uri, RDF.type, schema.Person))
        g.add((person_uri, schema.name, Literal(row["name"])))
        g.add((person_uri, schema.email, Literal(row["email"])))
        g.add((person_uri, schema.birthDate, Literal(row["birthdate"], datatype=XSD.date)))
        print(f"Processed row {index} successfully.")
        
              
    except Exception as e:
        print(f"Error processing row {index}: {e}")
# Out:
# Processed row 0 successfully.
# Processed row 1 successfully.

# %%
headers= df_events.columns.tolist()
for index, row in df_events.iterrows():
    try:
        # Validate required fields exist
        if pd.isna(row['title']):
            print(f"Row {index} skipped: 'title' missing.")
            continue

        event_uri = URIRef(f"{ex}event_{row['event_id']}")
        g.add((event_uri, RDF.type, schema.Event))
        g.add((event_uri, schema.name, Literal(row["title"])))
        g.add((event_uri, schema.startDate, Literal(row["date"], datatype=XSD.date)))

        organiser_uri = ex[f"person/{row['organiser_id']}"]
        g.add((event_uri, schema.organizer, organiser_uri))
        print(f"Processed row {index} successfully.")
        
              
    except Exception as e:
        print(f"Error processing row {index}: {e}")
# Out:
# Processed row 0 successfully.
# Processed row 1 successfully.

# %%
# Save the RDF graph to a TTL file
output_file = "events_data.ttl"
g.serialize(destination=output_file, format='turtle')
print(f"RDF graph saved to {output_file}")

# Optional: Print the TTL content to see what was generated
print("\nGenerated TTL content:")
print(g.serialize(format='turtle'))
# Out:
# RDF graph saved to events_data.ttl
#
# Generated TTL content:
# @prefix ex: <http://example.org/id#> .
# @prefix schema1: <https://schema.org/#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:event_E100 a schema1:Event ;
#     schema1:name "Health Workshop" ;
#     schema1:organizer <http://example.org/id#person/1> ;
#     schema1:startDate "0101-01-01"^^xsd:date .
#
# ex:event_E101 a schema1:Event ;
#     schema1:name "Data Summit" ;
#     schema1:organizer <http://example.org/id#person/2> ;
#     schema1:startDate "1501-01-01"^^xsd:date .
#
# <http://example.org/id#person/1> a schema1:Person ;
#     schema1:birthDate "1201-01-01"^^xsd:date ;
#     schema1:email "alice@example.org" ;
#     schema1:name "Alice Doe" .
#
# <http://example.org/id#person/2> a schema1:Person ;
#     schema1:birthDate "3001-01-01"^^xsd:date ;
#     schema1:email "bob@example.org" ;
#     schema1:name "Bob Smith" .
